# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import plotly.figure_factory as ff
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
# Out:
# /Users/jchen056/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # data integration

# %%
weather=pd.read_csv("Data/weather.csv")
weather.head(2)
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 20 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  629 non-null    object
#  1   NAME     629 non-null    object
#  2   DATE     629 non-null    object
#  3   AWND     627 non-null    float64
#  4   PRCP     629 non-null    float64
#  5   SNOW     629 non-null    float64
#  6   SNWD     629 non-null    float64
#  7   TAVG     0 non-null      float64
#  8   TMAX     629 non-null    int64
#  9   TMIN     629 non-null    int64
#  10  WDF2     627 non-null    float64
#  11  WDF5     626 non-null    float64
#  12  WSF2     627 non-null    float64
#  13  WSF5     626 non-null    float64
#  14  WT01     237 non-null    float64
#  15  WT02     22 non-null     float64
#  16  WT03     57 non-null     float64
#  17  WT04     1 non-null      float64
#  18  WT06     2 non-null      float64
#  19  WT08     111 non-null    float64
# ...

# %%
weather['Date']=weather['DATE'].apply(lambda x: datetime.strptime(x,"%Y-%m-%d"))

fig, ax = plt.subplots()
ax.plot(weather['Date'], weather['TMIN'],label="TMIN")
ax.plot(weather['Date'], weather['TMAX'],label="TMAX")
plt.legend(loc='lower right')
plt.show()

# %%
weather['Date'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
hourly_data=pd.read_csv("/Users/jchen056/Data/MTA_Subway_Hourly_Ridership__Beginning_February_2022.csv")
hourly_data["datetime"]=hourly_data["transit_timestamp"].apply(lambda x: datetime.strptime(x,"%m/%d/%Y %I:%M:%S %p"))
hourly_data.head()
# Out:
#         transit_timestamp station_complex_id station_complex borough routes  \
# 0  08/04/2022 04:00:00 AM               H007        1 Av (L)       M      L
# 1  02/13/2023 03:00:00 AM               H007        1 Av (L)       M      L
# 2  03/08/2023 04:00:00 AM               H007        1 Av (L)       M      L
# 3  03/23/2023 03:00:00 AM               H007        1 Av (L)       M      L
# 4  04/03/2023 05:00:00 AM               H007        1 Av (L)       M      L
#
#   payment_method  ridership  transfers   latitude  longitude  \
# 0           omny         11          0  40.730953 -73.981628
# 1           omny         10          0  40.730953 -73.981628
# 2           omny          4          0  40.730953 -73.981628
# 3           omny         10          0  40.730953 -73.981628
# 4           omny         28          0  40.730953 -73.981628
#
#                                     Georeference  \
# 0  POINT (-73.98162841796875 40.730953216552734)
# ...

# %%
hourly_data['date']=hourly_data['datetime'].apply(lambda x: datetime(x.year, x.month, x.day))

# %%
daily_data=hourly_data.groupby('date')['ridership'].agg(['mean','std','sum']).reset_index()
daily_data.head()
# Out:
#         date        mean         std      sum
# 0 2022-02-01  379.393740  700.056997  3806078
# 1 2022-02-02  430.612071  783.608966  4337986
# 2 2022-02-03  431.317590  778.698571  4337761
# 3 2022-02-04  400.395670  691.707099  4031584
# 4 2022-02-05  238.030606  417.928737  2333176

# %%
daily_date_with_weather=pd.merge(daily_data,weather,how='left',left_on='date',right_on='Date')
daily_date_with_weather.head()
# Out:
#         date        mean         std      sum      STATION  \
# 0 2022-02-01  379.393740  700.056997  3806078  USW00094728
# 1 2022-02-02  430.612071  783.608966  4337986  USW00094728
# 2 2022-02-03  431.317590  778.698571  4337761  USW00094728
# 3 2022-02-04  400.395670  691.707099  4031584  USW00094728
# 4 2022-02-05  238.030606  417.928737  2333176  USW00094728
#
#                           NAME        DATE  AWND  PRCP  SNOW  ...   WDF5  \
# 0  NY CITY CENTRAL PARK, NY US  2022-02-01  5.14  0.00   0.0  ...   50.0
# 1  NY CITY CENTRAL PARK, NY US  2022-02-02  2.91  0.00   0.0  ...  140.0
# 2  NY CITY CENTRAL PARK, NY US  2022-02-03  3.80  0.42   0.0  ...  230.0
# 3  NY CITY CENTRAL PARK, NY US  2022-02-04  6.71  0.72   0.0  ...  350.0
# 4  NY CITY CENTRAL PARK, NY US  2022-02-05  8.72  0.00   0.0  ...  300.0
#
#    WSF2  WSF5  WT01  WT02  WT03  WT04  WT06  WT08       Date
# 0  13.0  17.0   NaN   NaN   NaN   NaN   NaN   NaN 2022-02-01
# ...

# %%
daily_date_with_weather["Avg_Temperature"]=(daily_date_with_weather['TMIN']+daily_date_with_weather["TMAX"])/2
# daily_date_with_weather[['Avg_Temperature',"sum"]].corr()
# plt.hist(daily_date_with_weather['Avg_Temperature'])
# plt.hist(daily_date_with_weather['sum'])

#assign temperature to bins
daily_date_with_weather["Avg_Temperature"].min()#11 F
daily_date_with_weather["Avg_Temperature"].max()#87.5 F
def temperature_bin(temp):
    temperature_bins=np.arange(10,100,5)
    for i in np.flip(temperature_bins):
        if temp>=i:
            return str(i)+'+'
    return 'Below 10'
temperature_bin(100)

daily_date_with_weather['Temperature_Bin']=daily_date_with_weather['Avg_Temperature'].apply(temperature_bin)
daily_date_with_weather.groupby('Temperature_Bin')['sum'].mean().plot(kind='bar')

daily_date_with_weather.groupby('Temperature_Bin')['sum'].agg(["mean","std","size"])
# Out:
#                          mean           std  size
# Temperature_Bin
# 10+              1.414325e+06           NaN     1
# 15+              1.749028e+06           NaN     1
# 20+              3.148945e+06  2.026845e+06     7
# 25+              3.493317e+06  1.433179e+06     6
# 30+              3.634386e+06  1.061706e+06    19
# 35+              3.428007e+06  1.339560e+06    43
# 40+              3.298030e+06  1.064049e+06    50
# 45+              3.487442e+06  1.291178e+06    53
# 50+              3.134296e+06  8.530279e+05    58
# 55+              3.449405e+06  1.458272e+06    52
# 60+              3.993647e+06  1.484887e+06    59
# 65+              4.092486e+06  2.043598e+06    56
# 70+              4.543869e+06  2.066155e+06    71
# 75+              4.282542e+06  1.889951e+06    81
# 80+              4.014557e+06  2.051421e+06    46
# 85+              3.301070e+06  1.936620e+06     7

# %%
prcp_mean=daily_date_with_weather['PRCP'].mean()
prcp_std=daily_date_with_weather['PRCP'].std()

print(prcp_mean,prcp_std,daily_date_with_weather['PRCP'].median())
# daily_date_with_weather['PRCP'].describe()
#rain measurement: https://www.weathershack.com/static/ed-rain-measurement.html
def prcp_bins(prcp):
    if prcp<0.1:#precipitation not high
        return "low prcp"
    elif prcp<=0.3:
        return "moderate prcp"
    else:
        return "heavy prcp"
daily_date_with_weather['PRCP_Bin']=daily_date_with_weather['PRCP'].apply(prcp_bins)
daily_date_with_weather.head()
daily_date_with_weather.groupby('PRCP_Bin')['sum'].agg(['mean','std','size'])
# Out:
# 0.14383606557377052 0.3879524449183895 0.0
#                        mean           std  size
# PRCP_Bin
# heavy prcp     3.744033e+06  1.529597e+06    89
# low prcp       3.767890e+06  1.674953e+06   468
# moderate prcp  4.132228e+06  1.925750e+06    53

# %%
# plt.hist(daily_date_with_weather['Avg_Temperature'])
# daily_date_with_weather['Avg_Temperature'].mean()
# plt.hist(daily_date_with_weather['PRCP'])
daily_date_with_weather['PRCP'].std()
plt.hist(daily_date_with_weather['SNOW'])
daily_date_with_weather['SNOW'].mean()
daily_date_with_weather['SNOW'].std()
# Out:
# 0.08722869631132903

# %%
daily_date_with_weather['SNWD'].max()
# Out:
# 5.9

# %%
fig = make_subplots(rows=4, cols=4,
                    subplot_titles=("Temperature Distribution",
                                    "Precipitation Distribution",
                                    "Snowfall Distribution",
                                    "Snow Depth Distribution",
                                   '','','','',
                                    '','','','',
                                    'Ridership by Temperature','Ridersip by Precipitation'
                                   ))
# temp_dist = ff.create_distplot([daily_date_with_weather.Avg_Temperature.to_list()],
#                          group_labels=["Temperature"], bin_size=5)
labels=["Temperature","Precipitation","Snowfall"," Snow Depth"]
colors=["blue","red","green","orange"]
parameters_bins=['Temperature_Bin','PRCP_Bin']
for i,parameter in enumerate(['Avg_Temperature','PRCP',"SNOW","SNWD"]):
    weather_distribution=px.histogram(daily_date_with_weather, x=parameter,
                                      nbins=20)
    fig.add_trace(weather_distribution.data[0],row=1,col=i+1)
    fig.update_xaxes(title_text=labels[i],row=1,col=i+1)
    weather_distribution2=px.scatter(x=daily_date_with_weather[parameter],
                                   y=np.random.normal(loc=0,scale=0.01,
                                                      size=len(daily_date_with_weather[parameter])
                                                     ))
    fig.add_trace(weather_distribution2.data[0],row=2,col=i+1)   
    fig.update_xaxes(title_text=labels[i],row=2,col=i+1)
    
    weather_box=px.box(daily_date_with_weather, x=parameter)
    fig.add_trace(weather_box.data[0],row=3,col=i+1)
    fig.update_xaxes(title_text=labels[i],row=3,col=i+1)
fig.update_yaxes(title_text="Count",row=1,col=1)

for i,parameter_bin in enumerate(parameters_bins):
    weather_into_bins=daily_date_with_weather.groupby(parameter_bin)['sum'].agg(['mean','std','size'])
    fig.add_trace(go.Bar(x=weather_into_bins.index,
                    y=weather_into_bins['mean'],
                    error_y=dict(type='data',array=weather_into_bins['std'].to_list()),
                     showlegend=False
                    ),row=4,col=i+1)
fig.update_yaxes(title_text="Average Total Daily Ridership",row=4,col=1)
fig.update_layout(height=800, width=1000,title_text="Weather Analysis")
fig.show()
# Out:
# <div>                            <div id="46bddb50-b74b-41d1-97e8-c73bda8678ad" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46bddb50-b74b-41d1-97e8-c73bda8678ad")) {                    Plotly.newPlot(                        "46bddb50-b74b-41d1-97e8-c73bda8678ad",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Avg_Temperature=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":20,"offsetgroup":"","orientation":"v","showlegend":false,"x":[29.5,39.5,47.0,41.5,23.0,23.5,33.5,38.5,37.5,45.5,47.5,50.5,33.5,20.5,23.0,38.5,58.5,45.0,31.5,28.5,43.5,49.0,51.5,32.0,33.5,30.5,38.0,31.0,39.5,46.0,36.0,29.0,39.0,55.5,62.0,44.5,37.0,42.0,47.5,36.0,28.5,44
# ...

# %%
fig.write_html("visualizations/weather.html")

# %%
daily_date_with_weather.head()
# Out:
#         date        mean         std      sum      STATION  \
# 0 2022-02-01  379.393740  700.056997  3806078  USW00094728
# 1 2022-02-02  430.612071  783.608966  4337986  USW00094728
# 2 2022-02-03  431.317590  778.698571  4337761  USW00094728
# 3 2022-02-04  400.395670  691.707099  4031584  USW00094728
# 4 2022-02-05  238.030606  417.928737  2333176  USW00094728
#
#                           NAME        DATE  AWND  PRCP  SNOW  ...  WT01  WT02  \
# 0  NY CITY CENTRAL PARK, NY US  2022-02-01  5.14  0.00   0.0  ...   NaN   NaN
# 1  NY CITY CENTRAL PARK, NY US  2022-02-02  2.91  0.00   0.0  ...   1.0   NaN
# 2  NY CITY CENTRAL PARK, NY US  2022-02-03  3.80  0.42   0.0  ...   1.0   1.0
# 3  NY CITY CENTRAL PARK, NY US  2022-02-04  6.71  0.72   0.0  ...   1.0   NaN
# 4  NY CITY CENTRAL PARK, NY US  2022-02-05  8.72  0.00   0.0  ...   NaN   NaN
#
#    WT03  WT04  WT06  WT08       Date  Avg_Temperature  Temperature_Bin  \
# ...

# %%
# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go.Scatter(x=daily_date_with_weather.date,
                        y=daily_date_with_weather['sum'],
                        name="Temperature"),
             secondary_y=False)
# fig.add_trace(go.Scatter(x=daily_date_with_weather.date,
#                         y=daily_date_with_weather['Avg_Temperature'],
#                         name="Average Temperature")
#                         secondary_y=True)

# Add figure title
fig.update_layout(
    title_text="Daily Time Series for Total Ridership and Temperature"
)
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="<b>Temperature</b> Fahrenheit", secondary_y=True)
fig.update_yaxes(title_text="<b>Total Ridership</b>", secondary_y=False)
# Out:
# <div>                            <div id="6d01ee86-baa5-4db1-b0a1-26e3f09d8ed4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d01ee86-baa5-4db1-b0a1-26e3f09d8ed4")) {                    Plotly.newPlot(                        "6d01ee86-baa5-4db1-b0a1-26e3f09d8ed4",                        [{"name":"Temperature","x":["2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-05T00:00:00","2022-02-06T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-12T00:00:00","2022-02-13T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00",
# ...
